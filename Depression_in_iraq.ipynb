# %% [markdown]
# <a href="https://colab.research.google.com/github/yada01/Statistics-Of-Depresssion-in-Iraq/blob/main/Depression_in_iraq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as st

# %%
data ='https://raw.githubusercontent.com/yada01/Statistics-Of-Depresssion-in-Iraq/main/Dataset%20for%20cases%20in%20Iraq.csv'

# %%
mydata = pd.read_csv(data)

# %%
mydata.head(5)
# Out:
#    Unnamed: 0  Gender   Age  Weight sleep problems sucude attends  \
# 0           0    male  20.0    80.0             no            yes
# 1           1    male  21.0    78.0      sometimes             no
# 2           2  female  20.0    67.0      sometimes             no
# 3           3    male  23.0    78.0      sometimes             no
# 4           4    male  22.0    78.0             no            yes
#
#    dipression ritio Infected relatives shock related diseases  \
# 0              10.0                yes   yes               no
# 1               6.0                 no    no               no
# 2               7.0                 no    no               no
# 3               8.0                 no    no               no
# 4               1.0                yes    no              yes
#
#   اAcademic performance
# 0                   yes
# 1                    no
# 2                    no
# 3                   yes
# 4           not student

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             296 non-null    int64
#  1   Gender                 294 non-null    object
#  2   Age                    290 non-null    float64
#  3   Weight                 244 non-null    float64
#  4   sleep problems         295 non-null    object
#  5   sucude attends         294 non-null    object
#  6   dipression ritio       294 non-null    float64
#  7   Infected relatives     292 non-null    object
#  8   shock                  294 non-null    object
#  9   related diseases       295 non-null    object
#  10  اAcademic performance  293 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 25.6+ KB

# %%
mydata.describe()
# Out:
#        Unnamed: 0         Age      Weight  dipression ritio
# count  296.000000  290.000000  244.000000        294.000000
# mean   147.500000   22.768966   64.401230          5.340136
# std     85.592056    9.691705   17.703517          2.717650
# min      0.000000   15.000000   20.000000          1.000000
# 25%     73.750000   19.000000   54.750000          3.000000
# 50%    147.500000   20.500000   62.000000          5.000000
# 75%    221.250000   22.000000   70.250000          7.750000
# max    295.000000  101.000000  202.000000         10.000000

# %%
mydata.hist(figsize=(30,40))
plt.show()

# %%
mydata.hist(['Age'], figsize=(30,40))
plt.show()

# %%
sns.boxplot(x="Gender", y="Age", data=mydata)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
pd.crosstab(mydata['sucude attends'],mydata['Gender'] )
# Out:
# Gender          female  male
# sucude attends
# no                 146   104
# yes                 27    16

# %%
pd.crosstab(mydata['dipression ritio'],mydata['Gender'] )
# Out:
# Gender            female  male
# dipression ritio
# 1.0                   17    17
# 2.0                    8    18
# 3.0                   15    10
# 4.0                   16     9
# 5.0                   26    14
# 6.0                   18    11
# 7.0                   26    14
# 8.0                   24    13
# 9.0                   14     3
# 10.0                  10    10

# %%
sns.countplot(x="dipression ritio", hue="Gender", data=mydata)
# Out:
# <Axes: xlabel='dipression ritio', ylabel='count'>

# %%
sns.pairplot(mydata)

# %%
mydata['Age'].std()
# Out:
# 9.69170456289537

# %%
sns.distplot(mydata['Age'])
# Out:
# <ipython-input-16-4547901642e6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(mydata['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
mydata.hist(by='Gender',column = 'Age')
# Out:
# array([<Axes: title={'center': 'female'}>,
#        <Axes: title={'center': 'male'}>], dtype=object)

# %%
mydata.hist(by='Gender',column = 'sleep problems')
# Out:
# array([<Axes: title={'center': 'female'}>,
#        <Axes: title={'center': 'male'}>], dtype=object)

# %%
mydata.hist(by='Gender',column = 'Infected relatives')
# Out:
# array([<Axes: title={'center': 'female'}>,
#        <Axes: title={'center': 'male'}>], dtype=object)

# %%
mydata.hist(by='Gender',column = 'اAcademic performance')
# Out:
# array([<Axes: title={'center': 'female'}>,
#        <Axes: title={'center': 'male'}>], dtype=object)

# %%
mydata.hist(by='Gender',column = 'Weight')
# Out:
# array([<Axes: title={'center': 'female'}>,
#        <Axes: title={'center': 'male'}>], dtype=object)

# %%
corr = mydata.corr()
corr
# Out:
#                   Unnamed: 0       Age    Weight  dipression ritio
# Unnamed: 0          1.000000  0.243487  0.003498         -0.164517
# Age                 0.243487  1.000000  0.499478         -0.163323
# Weight              0.003498  0.499478  1.000000         -0.002373
# dipression ritio   -0.164517 -0.163323 -0.002373          1.000000

# %%
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots()
_ = plt.hist(mydata['Age'], color = 'lightgreen')

# %%
xbar = mydata['Age'].mean()
xbar
# Out:
# 22.76896551724138

# %%
fig, ax = plt.subplots()
plt.axvline(x = mydata['Age'].mean(), color='orange')
_ = plt.hist(mydata['Age'], color = 'lightgray')

# %%
mydata['Age'].median()
# Out:
# 20.5

# %%
fig, ax = plt.subplots()
plt.axvline(x = np.mean(mydata['Age']), color='orange')
plt.axvline(x = mydata['Age'].median(), color='green')
_ = plt.hist(mydata['Age'], color = 'lightgray')

# %%
mydata['Age'].var()
# Out:
# 93.92913733444696

# %%
mydata['Age'].var()**(1/2)
# Out:
# 9.69170456289537

# %%
sigma = mydata['Age'].std()
sigma
# Out:
# 9.69170456289537

# %%
fig, ax = plt.subplots()
plt.axvline(x = xbar, color='orange')
plt.axvline(x = xbar+sigma, color='olivedrab')
plt.axvline(x = xbar-sigma, color='olivedrab')
_ = plt.hist(mydata['Age'], color = 'lightgray')

# %%
x=mydata['Age']

# %%
sigma/(x.size)**(1/2)
# Out:
# 0.563318885419643

# %%
st.sem(x, ddof=0)
# Out:
# nan

# %%
sns.set_style('ticks')

# %%
_ = sns.displot(mydata['Age'], kde=True)

# %%
mydata['Age'].std()
# Out:
# 9.69170456289537

# %%
x=mydata['Age']

# %%
x_sample = np.random.choice(x, size=10, replace=False)
x_sample
# Out:
# array([23., 20., 21., 22., 21., 21., 20., 21., 20., 57.])

# %%
x_sample.mean()
# Out:
# 24.6
